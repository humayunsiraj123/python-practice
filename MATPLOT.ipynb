# %% [markdown]
# # IOT SECTION C
# # HUMAYUN SIRAJ
# # MATPLOTLIB PRACTICE
# # 30 12 2020

# %%
import matplotlib.pyplot as plt 
from random import *

y=[randint(1,99) for i in range(98)]
x=list(range(1,99))

plt.xlabel("time")
plt.ylabel("magnitude")

plt.plot(x,y)

# %%
import matplotlib.pyplot as plt 
from random import *

y=[randint(1,99) for i in range(98)]
x=list(range(1,99))
y1=[randint(1,)]
plt.xlim(1,150)
plt.ylim(1,150)
plt.xlabel("x range")
plt.ylabel("Random no ")


plt.plot(x,y)

# %%
from math import *
import numpy as np
a=np.arange(0.001,0.1,0.001)
t=list(a)
Vc=3.35
Vm=2.35
fc=350000.0
fm=300.0
a=[]
for i in t:
    Vam=Vc*sin((2.0*pi*fc*i))+Vm*sin(((2.0*pi*fm*i)))*sin((2.0*pi*fc*i))
    a.append(Vam)
    

plt.plot(t,a)
plt.show()

# %%
import matplotlib.pyplot as plt 
from random import *

y=[randint(1,99) for i in range(98)]
x=list(range(1,99))
y1=[randint(1,99) for i in range(98)]
plt.xlabel("x range")
plt.ylabel("Random no ")
plt.legend()

plt.plot(x,y,label="g1")
plt.plot(x,y1,label="g2")
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt

#Carrier wave c(t)=A_c*cos(2*pi*f_c*t)
#Modulating wave m(t)=A_m*cos(2*pi*f_m*t)
#Modulated wave s(t)=A_c[1+mu*cos(2*pi*f_m*t)]cos(2*pi*f_c*t)

A_c = float(input('Enter carrier amplitude: '))
f_c = float(input('Enter carrier frquency: '))
A_m = float(input('Enter message amplitude: '))
f_m = float(input('Enter message frquency: '))
modulation_index = float(input('Enter modulation index: '))

t = np.linspace(0, 1, 1000)

carrier = A_c*np.cos(2*np.pi*f_c*t)
modulator = A_m*np.cos(2*np.pi*f_m*t)
product = A_c*(1+modulation_index*np.cos(2*np.pi*f_m*t))*np.cos(2*np.pi*f_c*t)

plt.subplot(3,1,1)
plt.title('Amplitude Modulation')
plt.plot(modulator,'g')
plt.ylabel('Amplitude')
plt.xlabel('Message signal')

plt.subplot(3,1,2)
plt.plot(carrier, 'r')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')

plt.subplot(3,1,3)
plt.plot(product, color="purple")
plt.ylabel('Amplitude')
plt.xlabel('AM signal')

plt.subplots_adjust(hspace=1)
plt.rc('font', size=15)
fig = plt.gcf()
fig.set_size_inches(16, 9)

fig.savefig('Amplitude Modulation.png', dpi=100)
# Out:
# Enter carrier amplitude: 5
# Enter carrier frquency: 20000
# Enter message amplitude: 2
# Enter message frquency: 200
# Enter modulation index: 0.8

# %%
year=[1960,1970,1980,1990,2000,2010]
pop_pakistan=[44.91,58.09,78.07,107.7,138.5,170.6]
pop_india=[449.48,553.57,696.783,870.133,1000.4,1309.4]
plt.plot(year,pop_pakistan,color="g",label="pakistan")
plt.plot(year,pop_india,color='red',label="india")
plt.legend()
plt.xlabel("years")
plt.ylabel("Population in thousands")
# Out:
# Text(0, 0.5, 'Population in thousands')

# %%
x=np.linespace(-pi,pi,100)
plot(x,sin(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-997375f3b57b> in <module>
# ----> 1 x=np.linespace(-pi,pi,100)
#       2 plot(x,sin(x))
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     217                 return Tester
#     218             else:
# --> 219                 raise AttributeError("module {!r} has no attribute "
#     220                                      "{!r}".format(__name__, attr))
#     221
#
# AttributeError: module 'numpy' has no attribute 'linespace'
